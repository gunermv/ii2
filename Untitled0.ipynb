# %% [markdown]
# <a href="https://colab.research.google.com/github/gunermv/ii2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+2
# Out:
# 4

# %% [markdown]
# # Новый раздел

# %% [markdown]
# gjkh h k**ljj kl; jj![зеленые_карточки.png](data:image/png;base64,...)**  ; jkldj;fskj dg;
